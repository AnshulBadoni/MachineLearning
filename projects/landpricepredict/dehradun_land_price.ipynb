# %%
import pandas as pd

# %%
df = pd.read_csv('dehradun_land_price.csv')
df
# Out:
#             zone town/village    area_type agriculture  \
# 0    Bhaniyawala          yes  residential         yes
# 1    Bhaniyawala          yes  residential         yes
# 2    Bhaniyawala          yes  residential         yes
# 3    Bhaniyawala          yes  residential         yes
# 4    Bhaniyawala          yes  residential         yes
# ..           ...          ...          ...         ...
# 611   Vikasnagar           no   commercial          no
# 612   Vikasnagar           no   commercial          no
# 613   Vikasnagar           no   commercial          no
# 614   Vikasnagar           no   commercial          no
# 615   Vikasnagar           no   commercial          no
#
#      services(transport,hospital,water supply,education,market)
# 0                                                    1
# 1                                                    5
# 2                                                    4
# 3                                                    3
# ...
